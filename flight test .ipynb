# %%
import pandas as pd

# %%
df = pd.read_excel("Test_set.xlsx")

# %%
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
df.shape
# Out:
# (2671, 10)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc = OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='Airline',y='Date_of_Journey',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Date_of_Journey'>

# %%
sns.lineplot(x='Airline',y='Date_of_Journey',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Date_of_Journey'>

# %%
sns.relplot(x='Airline',y='Date_of_Journey',data=df)

# %%
sns.regplot(x='Airline',y='Date_of_Journey',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Date_of_Journey'>

# %%
sns.scatterplot(x='Source',y='Destination',data=df)
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Destination'>

# %%
sns.scatterplot(x='Route',y='Dep_Time',data=df)
# Out:
# <AxesSubplot:xlabel='Route', ylabel='Dep_Time'>

# %%
sns.relplot(x='Route',y='Dep_Time',data=df)

# %%
sns.regplot(x='Route',y='Dep_Time',data=df)
# Out:
# <AxesSubplot:xlabel='Route', ylabel='Dep_Time'>

# %%
sns.scatterplot(x='Airline',y='Duration',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Duration'>

# %%
sns.lineplot(x='Airline',y='Duration',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Duration'>

# %%
sns.regplot(x='Airline',y='Duration',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Duration'>

# %%
sns.relplot(x='Airline',y='Duration',data=df)

# %%
sns.scatterplot(x='Date_of_Journey',y='Route',data=df)
# Out:
# <AxesSubplot:xlabel='Date_of_Journey', ylabel='Route'>

# %%
sns.relplot(x='Date_of_Journey',y='Route',data=df)

# %%
sns.regplot(x='Date_of_Journey',y='Route',data=df)
# Out:
# <AxesSubplot:xlabel='Date_of_Journey', ylabel='Route'>

# %%
sns.relplot(x='Date_of_Journey',y='Route',data=df)

# %%
sns.scatterplot(x='Dep_Time',y='Duration',data=df)
# Out:
# <AxesSubplot:xlabel='Dep_Time', ylabel='Duration'>

# %%
sns.relplot(x='Dep_Time',y='Duration',data=df)

# %%
sns.regplot(x='Dep_Time',y='Duration',data=df)
# Out:
# <AxesSubplot:xlabel='Dep_Time', ylabel='Duration'>

# %%
sns.lineplot(x='Dep_Time',y='Duration',data=df)
# Out:
# <AxesSubplot:xlabel='Dep_Time', ylabel='Duration'>

# %%
sns.scatterplot(x='Airline',y='Dep_Time',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Dep_Time'>

# %%
sns.relplot(x='Airline',y='Dep_Time',data=df)

# %%
sns.lineplot(x='Airline',y='Dep_Time',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Dep_Time'>

# %%
sns.regplot(x='Airline',y='Dep_Time',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Dep_Time'>

# %%
sns.scatterplot(x='Date_of_Journey',y='Duration',data=df)
# Out:
# <AxesSubplot:xlabel='Date_of_Journey', ylabel='Duration'>

# %%
sns.lineplot(x='Date_of_Journey',y='Duration',data=df)
# Out:
# <AxesSubplot:xlabel='Date_of_Journey', ylabel='Duration'>

# %%
sns.relplot(x='Date_of_Journey',y='Duration',data=df)

# %%
sns.regplot(x='Date_of_Journey',y='Duration',data=df)
# Out:
# <AxesSubplot:xlabel='Date_of_Journey', ylabel='Duration'>

# %%
sns.scatterplot(x='Dep_Time',y='Total_Stops',data=df)
# Out:
# <AxesSubplot:xlabel='Dep_Time', ylabel='Total_Stops'>

# %%
sns.relplot(x='Dep_Time',y='Total_Stops',data=df)

# %%
sns.lineplot(x='Dep_Time',y='Total_Stops',data=df)
# Out:
# <AxesSubplot:xlabel='Dep_Time', ylabel='Total_Stops'>

# %%
sns.regplot(x='Dep_Time',y='Total_Stops',data=df)
# Out:
# <AxesSubplot:xlabel='Dep_Time', ylabel='Total_Stops'>

# %%
sns.scatterplot(x='Source',y='Route',data=df)
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Route'>

# %%
sns.relplot(x='Source',y='Route',data=df)

# %%
sns.lineplot(x='Source',y='Route',data=df)
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Route'>

# %%
sns.regplot(x='Source',y='Route',data=df)
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Route'>

# %%
sns.scatterplot(x='Airline',y='Source',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Source'>

# %%
sns.relplot(x='Airline',y='Source',data=df)

# %%
sns.lineplot(x='Airline',y='Source',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Source'>

# %%
sns.regplot(x='Airline',y='Source',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Source'>

# %%
sns.scatterplot(x='Airline',y='Destination',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Destination'>

# %%
sns.lineplot(x='Airline',y='Destination',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Destination'>

# %%
sns.relplot(x='Airline',y='Destination',data=df)

# %%
sns.regplot(x='Airline',y='Destination',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Destination'>

# %%
sns.scatterplot(x='Airline',y='Route',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Route'>

# %%
sns.regplot(x='Airline',y='Route',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Route'>

# %%
sns.relplot(x='Airline',y='Route',data=df)

# %%
sns.relplot(x='Airline',y='Route',data=df)

# %%
sns.scatterplot(x='Airline',y='Arrival_Time',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Arrival_Time'>

# %%
sns.regplot(x='Airline',y='Arrival_Time',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Arrival_Time'>

# %%
sns.relplot(x='Airline',y='Arrival_Time',data=df)

# %%
sns.lineplot(x='Airline',y='Arrival_Time',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Arrival_Time'>

# %%
sns.scatterplot(x='Airline',y='Total_Stops',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Total_Stops'>

# %%
sns.relplot(x='Airline',y='Total_Stops',data=df)

# %%
sns.regplot(x='Airline',y='Total_Stops',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Total_Stops'>

# %%
sns.relplot(x='Airline',y='Total_Stops',data=df)

# %%
sns.scatterplot(x='Route',y='Destination',data=df)
# Out:
# <AxesSubplot:xlabel='Route', ylabel='Destination'>

# %%
sns.scatterplot(x='Total_Stops',y='Source',data=df)
# Out:
# <AxesSubplot:xlabel='Total_Stops', ylabel='Source'>

# %%
sns.scatterplot(x='Duration',y='Source',data=df)
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Source'>

# %%
sns.scatterplot(x='Airline',y='Destination',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Destination'>

# %%
sns.scatterplot(x='Airline',y='Route',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Route'>

# %%
sns.scatterplot(x='Duration',y='Route',data=df)
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Route'>

# %%
sns.scatterplot(x='Duration',y='Airline',data=df)
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Airline'>
