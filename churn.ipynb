# %%
import pandas as pd

# %%
df = pd.read_csv('Telecom_customer_churn.csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
sns.countplot(data=df,x='Dependents',hue='Churn')
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(data=df,x='InternetService',hue='Churn')
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
sns.countplot(x='SeniorCitizen',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %%
sns.countplot(x='Partner',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='count'>

# %%
sns.countplot(x='Dependents',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(x='tenure',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='count'>

# %%
sns.countplot(x='PhoneService',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='PhoneService', ylabel='count'>

# %%
sns.countplot(x='MultipleLines',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
sns.countplot(x='InternetService',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
sns.countplot(x='OnlineSecurity',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='OnlineSecurity', ylabel='count'>

# %%
sns.countplot(x='OnlineBackup',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='OnlineBackup', ylabel='count'>

# %%
sns.countplot(x='DeviceProtection',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='DeviceProtection', ylabel='count'>

# %%
sns.countplot(x='TechSupport',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='TechSupport', ylabel='count'>

# %%
sns.countplot(x='StreamingTV',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='StreamingTV', ylabel='count'>

# %%
sns.countplot(x='StreamingMovies',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='StreamingMovies', ylabel='count'>

# %%
sns.countplot(x='Contract',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
sns.countplot(x='PaperlessBilling',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='PaperlessBilling', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='PaymentMethod',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='count'>

# %%
sns.histplot(df['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %%
sns.countplot(df['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.histplot(df['SeniorCitizen'])
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='Count'>

# %%
sns.histplot(df['Partner'])
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='Count'>

# %%
sns.histplot(df['Dependents'])
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='Count'>

# %%
sns.histplot(df['tenure'])
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Count'>

# %%
sns.histplot(df['PhoneService'])
# Out:
# <AxesSubplot:xlabel='PhoneService', ylabel='Count'>

# %%
sns.histplot(df['MultipleLines'])
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='Count'>

# %%
sns.histplot(df['InternetService'])
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='Count'>

# %%
sns.histplot(df['tenure'])
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Count'>

# %%
sns.histplot(df['PhoneService'])
# Out:
# <AxesSubplot:xlabel='PhoneService', ylabel='Count'>

# %%
sns.histplot(df['MultipleLines'])
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='Count'>

# %%
sns.histplot(df['InternetService'])
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='Count'>

# %%
sns.histplot(df['OnlineSecurity'])
# Out:
# <AxesSubplot:xlabel='OnlineSecurity', ylabel='Count'>

# %%
sns.histplot(df['OnlineBackup'])
# Out:
# <AxesSubplot:xlabel='OnlineBackup', ylabel='Count'>

# %%
sns.histplot(df['DeviceProtection'])
# Out:
# <AxesSubplot:xlabel='DeviceProtection', ylabel='Count'>

# %%
sns.histplot(df['TechSupport'])
# Out:
# <AxesSubplot:xlabel='TechSupport', ylabel='Count'>

# %%
sns.histplot(df['StreamingTV'])
# Out:
# <AxesSubplot:xlabel='StreamingTV', ylabel='Count'>

# %%
sns.histplot(df['StreamingMovies'])
# Out:
# <AxesSubplot:xlabel='StreamingMovies', ylabel='Count'>

# %%
sns.histplot(df['Contract'])
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='Count'>

# %%
sns.histplot(df['PaperlessBilling'])
# Out:
# <AxesSubplot:xlabel='PaperlessBilling', ylabel='Count'>

# %%
sns.histplot(df['PaymentMethod'])
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='Count'>

# %%
sns.histplot(df['MonthlyCharges'])
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Count'>

# %%
sns.scatterplot(x='gender',y='SeniorCitizen',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='SeniorCitizen'>

# %%
sns.scatterplot(x='gender',y='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Churn'>

# %%
sns.relplot(x='gender',y='Churn',data=df)

# %%
sns.scatterplot(x='Churn',y='MonthlyCharges',data=df)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='MonthlyCharges'>

# %%
sns.relplot(x='Churn',y='MonthlyCharges',data=df)

# %%
sns.scatterplot(x='PaymentMethod',y='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='Churn'>

# %%
sns.catplot(x='gender',y='SeniorCitizen',hue='Churn',data=df,kind='bar')

# %%
sns.scatterplot(x='Contract',y='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='Churn'>

# %%
sns.relplot(x='Contract',y='Churn',data=df)

# %%
sns.lineplot(x='Contract',y='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='Churn'>

# %%
sns.scatterplot(x='PaperlessBilling',y='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='PaperlessBilling', ylabel='Churn'>

# %%
sns.lineplot(x='PaperlessBilling',y='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='PaperlessBilling', ylabel='Churn'>

# %%
sns.relplot(x='PaperlessBilling',y='Churn',data=df)

# %%
sns.scatterplot(x='PaymentMethod',y='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='Churn'>

# %%
sns.relplot(x='PaymentMethod',y='Churn',data=df)

# %%
sns.lineplot(x='PaymentMethod',y='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='Churn'>

# %%
df.drop('customerID',axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
sns.distplot(df['MonthlyCharges'])
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>

# %%
df['MonthlyCharges'].skew()
# Out:
# -0.22052443394398033

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df['TotalCharges'].value_counts()
# Out:
# 20.2       11
#            11
# 19.75       9
# 19.65       8
# 19.9        8
#            ..
# 2553.7      1
# 2404.1      1
# 1024        1
# 5016.65     1
# 7320.9      1
# Name: TotalCharges, Length: 6531, dtype: int64

# %%
df['TotalCharges'].unique()
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.loc[df['TotalCharges']==" "]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
import numpy as np

# %%
df['TotalCharges']=df['TotalCharges'].replace(" ",np.nan)

# %%
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df['TotalCharges']=df['TotalCharges'].astype(float)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
median_value = df["TotalCharges"].median()

# %%
df["TotalCharges"].fillna(median_value,inplace = True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
sns.scatterplot(x='TotalCharges',y='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Churn'>

# %%
sns.relplot(x='TotalCharges',y='Churn',data=df)

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
sns.scatterplot(x='SeniorCitizen',y='PaymentMethod',hue='Churn',data = df)
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='PaymentMethod'>

# %%
sns.scatterplot(x='Dependents',y='PaymentMethod',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='PaymentMethod'>

# %%
sns.scatterplot(x='Dependents',y='Contract',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='Contract'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int32
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int32
#  3   Dependents        7043 non-null   int32
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int32
#  6   MultipleLines     7043 non-null   int32
#  7   InternetService   7043 non-null   int32
#  8   OnlineSecurity    7043 non-null   int32
#  9   OnlineBackup      7043 non-null   int32
#  10  DeviceProtection  7043 non-null   int32
#  11  TechSupport       7043 non-null   int32
#  12  StreamingTV       7043 non-null   int32
#  13  StreamingMovies   7043 non-null   int32
#  14  Contract          7043 non-null   int32
#  15  PaperlessBilling  7043 non-null   int32
# ...

# %%
df.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.504756       0.162147     0.483033     0.299588    32.371149
# std       0.500013       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count   7043.000000    7043.000000      7043.000000     7043.000000
# mean       0.903166       0.940508         0.872923        0.790004
# std        0.295752       0.948554         0.737796        0.859848
# ...

# %%
df['MonthlyCharges'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['TotalCharges'].plot.box()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['MonthlyCharges'])
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>

# %%
df['MonthlyCharges'].skew()
# Out:
# -0.22052443394398033

# %%
sns.distplot(df['TotalCharges'])
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Density'>

# %%
df['TotalCharges'].skew()
# Out:
# 0.9637890936414893

# %%
from scipy.stats import boxcox

# %%
df['TotalCharges']= boxcox(df['TotalCharges'],0)

# %%
df['TotalCharges'].skew()
# Out:
# -0.7549990627862947

# %%
sns.scatterplot(x='TotalCharges',y='MonthlyCharges',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='MonthlyCharges'>

# %%
sns.scatterplot(x='Contract',y='MonthlyCharges',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='MonthlyCharges'>

# %%
sns.scatterplot(x='Partner',y='Dependents',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='Dependents'>

# %%
sns.scatterplot(x='DeviceProtection',y='StreamingMovies',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='DeviceProtection', ylabel='StreamingMovies'>

# %%
sns.scatterplot(x='DeviceProtection',y='PaymentMethod',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='DeviceProtection', ylabel='PaymentMethod'>

# %%
sns.catplot(x='DeviceProtection',y='PaymentMethod',hue='Churn',data=df,kind='bar')

# %%
sns.scatterplot(x='MonthlyCharges',y='PaymentMethod',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='PaymentMethod'>

# %%
sns.scatterplot(x='Dependents',y='PaymentMethod',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='PaymentMethod'>

# %%
sns.catplot(x='Dependents',y='PaymentMethod',hue='Churn',data=df,kind='bar')

# %%
sns.scatterplot(x='tenure',y='PaymentMethod',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='PaymentMethod'>

# %%
sns.scatterplot(x='InternetService',y='PaymentMethod',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='PaymentMethod'>

# %%
sns.catplot(x='InternetService',y='PaymentMethod',hue='Churn',data=df,kind='bar')

# %%
sns.scatterplot(x='TechSupport',y='Contract',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='TechSupport', ylabel='Contract'>

# %%
sns.catplot(x='TechSupport',y='Contract',hue='Churn',data=df,kind='bar')

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874 -0.001808    0.010517  0.005106
# SeniorCitizen    -0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner          -0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents        0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure            0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService     -0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines    -0.006739       0.146185  0.142410   -0.024991  0.343032
# InternetService  -0.000863      -0.032310  0.000891    0.044590 -0.030359
# OnlineSecurity   -0.015017      -0.128221  0.150828    0.152166  0.325468
# OnlineBackup     -0.012057      -0.013632  0.153130    0.091015  0.370876
# DeviceProtection  0.000549      -0.021398  0.166330    0.080537  0.371105
# TechSupport      -0.006825      -0.151268  0.126733    0.133524  0.322942
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot= True)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.504756       0.162147     0.483033     0.299588    32.371149
# std       0.500013       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count   7043.000000    7043.000000      7043.000000     7043.000000
# mean       0.903166       0.940508         0.872923        0.790004
# std        0.295752       0.948554         0.737796        0.859848
# ...

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
y = df['Churn']

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int32

# %%
x= df.drop('Churn',axis=1)

# %%
x
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=50)

# %%
x_train.shape
# Out:
# (5634, 19)

# %%
y_train.shape
# Out:
# (5634,)

# %%
x_test.shape
# Out:
# (1409, 19)

# %%
y_test.shape
# Out:
# (1409,)

# %%
import sklearn
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
svc= SVC()
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.78708303761533
# [[959  82]
#  [218 150]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86      1041
#            1       0.65      0.41      0.50       368
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.66      0.68      1409
# weighted avg       0.77      0.79      0.77      1409

# %%
paramsv = {'kernel':['linear','poly','rbf'],
           'gamma':['scale','auto'],
            'degree':np.arange(1,10)}

# %%
#gc = GridSearchCV(SVC(),paramsv,cv=5)
#gc.fit(x,y)
#gc.best_params_

# %%
#Svc= SVC(kernel ='',gamma='',degree=1)
#Svc.fit(x_train,y_train)
#Svc.score(x_train,y_train)
#predSvc = Svc.predict(x_test)
#print(accuracy_score(y_test,predSvc))
#print(confusion_matrix(y_test,predSvc))
#print(classification_report(y_test,predSvc))

# %%
dtc= DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc = dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.7274662881476224
# [[832 209]
#  [175 193]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.81      1041
#            1       0.48      0.52      0.50       368
#
#     accuracy                           0.73      1409
#    macro avg       0.65      0.66      0.66      1409
# weighted avg       0.74      0.73      0.73      1409

# %%
paramdt = {'criterion':['gini','entropy'],'splitter':['best','random'],
            'max_depth': np.arange(1,10)}

# %%
gc = GridSearchCV(DecisionTreeClassifier(),paramdt,cv=5)

# %%
gc.fit(x,y)
gc.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'splitter': 'best'}

# %%
DTC= DecisionTreeClassifier(criterion='entropy',splitter='best',max_depth=5)
DTC.fit(x_train,y_train)
DTC.score(x_train,y_train)
predDTC = DTC.predict(x_test)
print(accuracy_score(y_test,predDTC))
print(confusion_matrix(y_test,predDTC))
print(classification_report(y_test,predDTC))
# Out:
# 0.794889992902768
# [[973  68]
#  [221 147]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87      1041
#            1       0.68      0.40      0.50       368
#
#     accuracy                           0.79      1409
#    macro avg       0.75      0.67      0.69      1409
# weighted avg       0.78      0.79      0.77      1409

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn = knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.7757274662881476
# [[897 144]
#  [172 196]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      1041
#            1       0.58      0.53      0.55       368
#
#     accuracy                           0.78      1409
#    macro avg       0.71      0.70      0.70      1409
# weighted avg       0.77      0.78      0.77      1409

# %%
paramkn = {'n_neighbors':np.arange(1,10),'weights':['uniform','distance'],'algorithm':['auto','ball_tree','kd_tree']}

# %%
gc = GridSearchCV(KNeighborsClassifier(),paramkn,cv=5)

# %%
gc.fit(x,y)
gc.best_params_
# Out:
# {'algorithm': 'ball_tree', 'n_neighbors': 8, 'weights': 'uniform'}

# %%
KNn = KNeighborsClassifier(n_neighbors=8,weights='uniform',algorithm='ball_tree')
KNn.fit(x_train,y_train)
KNn.score(x_train,y_train)
predKNn = KNn.predict(x_test)
print(accuracy_score(y_test,predKNn))
print(confusion_matrix(y_test,predKNn))
print(classification_report(y_test,predKNn))
# Out:
# 0.7899219304471257
# [[941 100]
#  [196 172]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1041
#            1       0.63      0.47      0.54       368
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.69      0.70      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
rfc.score(x_test, y_test)
predrfc = rfc.predict(x_test)
print(accuracy_score(y_test,predrfc))
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 0.7970191625266146
# [[940 101]
#  [185 183]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1041
#            1       0.64      0.50      0.56       368
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.70      0.71      1409
# weighted avg       0.79      0.80      0.79      1409

# %%
paramrf={'n_estimators':np.arange(1,10),'criterion':['gini','entropy'],
          'max_depth':np.arange(1,10)}

# %%
gc = GridSearchCV(RandomForestClassifier(),paramrf,cv=5)

# %%
gc.fit(x,y)
gc.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 6, 'n_estimators': 8}

# %%
Rfc = RandomForestClassifier(criterion='entropy',n_estimators=8,max_depth=6)
Rfc.fit(x_train, y_train)
Rfc.score(x_test, y_test)
predRfc = Rfc.predict(x_test)
print(accuracy_score(y_test,predRfc))
print(confusion_matrix(y_test,predRfc))
print(classification_report(y_test,predRfc))
# Out:
# 0.7963094393186657
# [[954  87]
#  [200 168]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87      1041
#            1       0.66      0.46      0.54       368
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.69      0.70      1409
# weighted avg       0.78      0.80      0.78      1409

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(svc,x,y,cv=5).mean())
# Out:
# 0.7894365160655525

# %%
print(cross_val_score(DTC,x,y,cv=5).mean())
# Out:
# 0.7946922986966902

# %%
print(cross_val_score(KNn,x,y,cv=5).mean())
# Out:
# 0.780917317246274

# %%
print(cross_val_score(Rfc,x,y,cv=5).mean())
# Out:
# 0.7992347288534745

# %%
import pickle

# %%
filename = 'churn.pkl'
pickle.dump(Rfc,open(filename,'wb'))
